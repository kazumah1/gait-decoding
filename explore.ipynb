# %%
import pandas as pd

# %%
data = pd.read_csv("data/gait_decoding_combined.csv")

# %%
data
# Out:
#         subject_id trial_id  time_seconds  eeg_Fp1  eeg_Fp2  eeg_F7  eeg_F3  \
# 0             SL01      T01         0.139      0.0      0.0     0.0     0.0
# 1             SL01      T01         0.142      0.0      0.0     0.0     0.0
# 2             SL01      T01         0.153      0.0      0.0     0.0     0.0
# 3             SL01      T01         0.163      0.0      0.0     0.0     0.0
# 4             SL01      T01         0.174      0.0      0.0     0.0     0.0
# ...            ...      ...           ...      ...      ...     ...     ...
# 3240216       SL08      T03      1439.960   1943.8   1770.9  1966.0  1557.8
# 3240217       SL08      T03      1439.970   1950.1   1774.9  1956.4  1554.8
# 3240218       SL08      T03      1439.980   1943.4   1763.4  1935.8  1553.7
# 3240219       SL08      T03      1439.990   1932.9   1747.5  1936.3  1554.0
# 3240220       SL08      T03      1440.000   1949.1   1759.8  1962.7  1549.9
#
# ...

# %%
SL08T01 = data[(data["subject_id"] == "SL08") & (data["trial_id"] == "T01")]
